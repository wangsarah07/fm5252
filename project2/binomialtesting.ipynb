# %% [markdown]
# Examples of Binomial Model Usage

# %%
import numpy as np
import pandas as pd
from binomialmodel import *

# %%
# option parameters 
S = 100    
K = 100   
T = 1      
r = 0.05   
q = 0     
sigma = 0.2  
n = 8

# %%
binomial_model(S, K, T, r, n, q, sigma, 'call', 'european')
# Out:
# price: 10.205099415991738
# delta: 0.632911260491806
# gamma: 0.021033064169009758
# vega: 0.363684963378752
# theta: -0.01724368212638261
# rho: 0.5308602597485113

# %%
binomial_model(S, K, T, r, n, q, sigma, 'put', 'european')
# Out:
# price: 5.3280418660631526
# delta: -0.3670887395081941
# gamma: 0.02103306416900984
# vega: 0.3636849633792405
# theta: -0.004212249521305722
# rho: -0.42036916634056176

# %%
binomial_model(S, K, T, r, n, q, sigma, 'call', 'american')
# Out:
# price: 10.205099415991738
# delta: 0.632911260491806
# gamma: 0.021033064169009758
# vega: 0.363684963378752
# theta: -0.01724368212638261
# rho: 0.5308602597485113

# %%
binomial_model(S, K, T, r, n, q, sigma, 'put', 'american')
# Out:
# price: 5.973503417209237
# delta: -0.3670887395081941
# gamma: 0.02103306416900984
# vega: 0.3636849633792405
# theta: -0.004212249521305722
# rho: -0.42036916634056176
